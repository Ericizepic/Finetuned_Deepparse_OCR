# %%
! pip install transformers datasets rouge-score nltk
! pip install -U accelerate
! pip install -U transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 6.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.5 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=ee2c98988efced7a01fb7cd7179dfb8d5eb1bce2a245e2263d14872db659a79b
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from transformers import T5Tokenizer, T5ForConditionalGeneration
from transformers import TrainingArguments, Trainer, EarlyStoppingCallback, DataCollatorForSeq2Seq
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import load_dataset, load_metric
import torch

# %%
file_dict = {
  "train" : "/content/drive/MyDrive/addr_std_training_data_5.csv",
}
data = load_dataset("csv", data_files = file_dict, skiprows=1, column_names = ["non-std-addres", "std-address"])
data = data["train"].train_test_split(test_size=0.2)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
model_path = ("/content/drive/MyDrive/t5_addr_std_5")
tokenizer = T5Tokenizer.from_pretrained(model_path)
model = T5ForConditionalGeneration.from_pretrained(model_path)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def preprocess_function(d):
    inputs = d["non-std-addres"]
    targets = d["std-address"]
    model_inputs = tokenizer(inputs, max_length=512, truncation=True)

    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=512, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_data = data.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/1587497 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:3892: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Exception ignored in: <function _xla_gc_callback at 0x7d98fe427a30>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# Map:   0%|          | 0/396875 [00:00<?, ? examples/s]

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)

from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

training_args = Seq2SeqTrainingArguments(
    output_dir="./content/drive/MyDrive",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=5,
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data["train"],
    eval_dataset=tokenized_data["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(

# %%
model.push_to_hub("Ericizepic/T5-Address_Std_v1", token="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")
# Out:
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Ericizepic/T5-Address_Std_v1/commit/f28c109b2e26d0396e25380a23d53c90f5d11b8e', commit_message='Upload T5ForConditionalGeneration', commit_description='', oid='f28c109b2e26d0396e25380a23d53c90f5d11b8e', pr_url=None, pr_revision=None, pr_num=None)

# %%
tokenizer.push_to_hub("Ericizepic/T5-Address_Std_v1", token="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")
# Out:
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Ericizepic/T5-Address_Std_v1/commit/17241709861dcbeb78db5c8bc686e65a05010861', commit_message='Upload tokenizer', commit_description='', oid='17241709861dcbeb78db5c8bc686e65a05010861', pr_url=None, pr_revision=None, pr_num=None)

# %%
input_ids = tokenizer("5500 yonge ave unit 123 toronto on", return_tensors="pt").input_ids
outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# 5500 yonge ave unit 123 toronto on

# %%
input_ids = tokenizer("5500 yonge st unit 123 tor onto on", return_tensors="pt").input_ids
outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# 5500 yonge st unit 123 toron on

# %%
input_ids = tokenizer("123-5500 yonge street north york on", return_tensors="pt").input_ids
outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# unit 123 5500 yonge st north york on

# %%
input_ids = tokenizer("123 abc street", return_tensors="pt").input_ids
outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# 123 abc st

# %%
input_ids = tokenizer("123abortavenueonca", return_tensors="pt").input_ids
outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# 123 abbot ave on ca

# %%
input_ids = tokenizer("halifaxns", return_tensors="pt").input_ids
outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1178: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# halifax ns

# %%
input_ids = tokenizer("62-687 king street west ca k7m 2g1", return_tensors="pt").input_ids
outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0], max_length=512, skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1178: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# unit 62 687 king street w ca k7m 2g1

# %%
input_ids = tokenizer("13-5401 timothy trwy st catharines l2m 1w9 ontarioca", return_tensors="pt").input_ids
outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# unit 13 5401 timothy twy st catharines

# %%
from huggingface_hub import notebook_login

# %%
notebook_login()
